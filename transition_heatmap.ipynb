# %%
import pandas as pd
import numpy as np
import csv
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import glob, os
import seaborn as sns

# %%
#import csv for traces

#with open('/Users/nadine/Documents/Zlatic_lab/close-loop/notes/Transition_mapBasin_ol_percent_short.csv', 'r') as csvfile:
#with open('/Users/nadine/Documents/Zlatic_lab/close-loop/notes/Transition_mapBasin_cl_percent.csv', 'r') as csvfile:
with open('/Users/nadine/Documents/Zlatic_lab/close-loop/permutation_test_results_Chen/handle-permutation-test-basic_preceed.csv') as csvfile:
    #df = pd.read_csv(csvfile, delim_whitespace=True, names=names)
    df = pd.read_csv(csvfile, delimiter = ',')
    #df = pd.read_csv(csvfile, delimiter = ',', header=None)
    
    
    print(df.head())
# Out:
#   handle   F      B       Q   non-F  non-B  non-Q
# 0      F NaN  0.035  0.0605  0.0759    NaN    NaN
# 1      B NaN    NaN  0.6990     NaN  0.579    NaN
# 2      Q NaN    NaN     NaN     NaN    NaN  0.119

# %%
#df1 = df.set_index('behavior pre optogenetic manipulation')
df1 = df.set_index('handle')
print(df1)
# Out:
#          F      B       Q   non-F  non-B  non-Q
# handle
# F      NaN  0.035  0.0605  0.0759    NaN    NaN
# B      NaN    NaN  0.6990     NaN  0.579    NaN
# Q      NaN    NaN     NaN     NaN    NaN  0.119

# %%
#cmap='RdYlGn_r'
#cmap='Blues'

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# To make the plot in the notebook and not in an extra window
# %matplotlib notebook 
ax = plt.axes()
sns.heatmap(df1,vmin=0.0001, vmax=0.005, cmap='RdYlGn_r',linewidths=0.5, linecolor='k', annot=True, square=True)
ax.set_title('Behavior transition (Cell type 1 activation in A4)')
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from matplotlib import colors
cmap = colors.ListedColormap(['red','orange','yellow','lightgrey'])
bounds=[0, 0.001, 0.01, 0.05, 1]
norm = colors.BoundaryNorm(bounds, cmap.N)

# %matplotlib notebook 
ax = plt.axes()
sns.heatmap(df1, cmap=cmap, norm =norm ,linewidths=0.5, linecolor='k', annot=True, square=True)
#ax.set_title('Behavior transition (Cell type 1 activation in A4)')
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>
