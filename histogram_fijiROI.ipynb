# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
with open('/Users/nadine/Desktop/difGausianFilter/tmp-lbl-Morphometry.csv', 'r') as csvfile:

    #df = pd.read_csv(csvfile, delim_whitespace=True, names=names)
    df = pd.read_csv(csvfile, delimiter = ',')
    print(df.head())
# Out:
#    Label  Area  Perimeter  Circularity  EulerNumber  Box.X.Min  Box.X.Max  \
# 0      1    17     14.518        1.014            1        275        280
# 1      2    14     12.948        1.049            1        298        302
# 2      3     1      2.682        1.748            1        289        290
# 3      4    33     20.762        0.962            1        252        259
# 4      5     6      8.600        1.019            1        266        269
#
#    Box.Y.Min  Box.Y.Max  Centroid.X  ...  OBox.Center.Y  OBox.Length  \
# 0         83         88     277.500  ...          85.50        5.657
# 1         86         90     300.000  ...          88.00        4.000
# 2         89         90     289.500  ...          89.50        1.000
# 3         90         96     255.106  ...          93.00        7.000
# 4         92         95     267.333  ...          93.25        3.536
#
#    OBox.Width  OBox.Orientation  GeodesicDiameter  Tortuosity  \
# 0       4.243             135.0             5.814       0.997
# 1       4.000               0.0             5.014       1.003
# 2       1.000               0.0             1.414       1.000
# 3       6.000               0.0             8.014       0.994
# 4       2.828              45.0             3.614       1.002
#
#    InscrDisc.Center.X  InscrDisc.Center.Y  InscrDisc.Radius  \
# 0                 277                  84                 2
# 1                 299                  87                 2
# 2                 289                  89                 1
# 3                 254                  93                 3
# 4                 267                  93                 2
#
#    GeodesicElongation
# 0               1.454
# 1               1.254
# 2               0.707
# 3               1.336
# 4               0.904
#
# [5 rows x 32 columns]

# %%
# %matplotlib notebook 
df.hist(column='Area', bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcdb9d1d550>]],
#       dtype=object)
