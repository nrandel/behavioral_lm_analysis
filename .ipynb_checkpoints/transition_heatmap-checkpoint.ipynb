# %%
import pandas as pd
import numpy as np
import csv
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import glob, os
import seaborn as sns

# %%
#import csv for traces

#with open('/Users/nadine/Documents/Zlatic_lab/close-loop/notes/LI100_L1_transitionPERC.csv', 'r') as csvfile:
#with open('/Users/nadine/Documents/Zlatic_lab/close-loop/notes/old/Transition_mapBasin_cl_per4.csv', 'r') as csvfile:
#with open('/Users/nadine/Documents/Zlatic_lab/close-loop/notes/Transition_mapBasin_cl_percent.csv', 'r') as csvfile:
#with open('/Users/nadine/Documents/Zlatic_lab/close-loop/permutation_test_results_Chen/basin-permutation-test-basic_succeed.csv') as csvfile:
    #df = pd.read_csv(csvfile, delim_whitespace=True, names=names)
    df = pd.read_csv(csvfile, delimiter = ',')
    #df = pd.read_csv(csvfile, delimiter = ',', header=None)
    
    
    print(df.head())

# %%
df1 = df.set_index('pre stim')
#df1 = df.set_index('basin')
print(df1)

# %%
#cmap='RdYlGn_r'
#cmap='Blues'

# %%
# for quick copy-paste dataframe

new_index = ['F', 'B', 'Q']
A4_events = pd.DataFrame(np.array([[43, 2, 0], [21, 5, 3], [27, 2, 38]]),
                   columns=['F', 'B', 'Q'], index = new_index)

A4_samples = pd.DataFrame(np.array([[13, 1, 0], [15, 3, 2], [7, 2, 7]]),
                   columns=['F', 'B', 'Q'], index = new_index)

# %%
new_index = ['F', 'B', 'Q']
A9_events = pd.DataFrame(np.array([[4, 0, 0], [0, 2, 18], [17, 0, 18]]),
                   columns=['F', 'B', 'Q'], index = new_index)

# %%
new_index = ['F', 'B', 'Q']
A4A9_events = pd.DataFrame(np.array([[47, 2, 0], [36, 7, 21], [44, 2, 56]]),
                   columns=['F', 'B', 'Q'], index = new_index)

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns

# To make the plot in the notebook and not in an extra window
# %matplotlib notebook 

fig = plt.figure()
ax = plt.axes()
#tilt x-axis labeling ~45degree
#plt.xticks(rotation=45)

#sns.heatmap(df1,vmin=0.0001, vmax=0.005, cmap='RdYlGn_r',linewidths=0.5, linecolor='k', annot=True, square=True)
sns.heatmap(A4_samples, cmap='tab10',linewidths=0.5, linecolor='w', annot=True, annot_kws={"size": 20}, square=True)


ax.set_title('Samples: Behavior transition close loop (A4))')
plt.show()

#plt.savefig("fig1.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# To make the plot in the notebook and not in an extra window
# %matplotlib notebook 

fig = plt.figure()
ax = plt.axes()
#tilt x-axis labeling ~45degree
#plt.xticks(rotation=45)

sns.heatmap(A4_events, cmap='hot',linewidths=0.5, linecolor='w', annot=True, annot_kws={"size": 20}, square=True)
#sns.heatmap(A4A9_events, cmap='hot',linewidths=0.5, linecolor='w', annot=True, annot_kws={"size": 20}, square=True)
#sns.heatmap(A9_events, cmap='hot',linewidths=0.5, linecolor='w', annot=True, annot_kws={"size": 20}, square=True)

ax.set_title('Events: Behavior transition close loop (A4)')
plt.show()

#plt.savefig("fig1.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Fisher Exact Test 2x2
import scipy

#reshape table
#A4 or A9 events
fb = A4_events[['F', 'B']]
fb1 = fb.iloc[0:2]

#fq A4 or A9 events
fq = A4_events.iloc[[0, 2], [0, 2]]

#bq # A4 or A9 events
bq = A4_events[['B', 'Q']]
bq1 = bq.iloc[1:3]

scipy.stats.fisher_exact(fb1, alternative='two-sided')
# Out:
# (5.119047619047619, 0.0913759074660202)

# %%
fb1
# Out:
#     F  B
# F  42  2
# B  21  5

# %%
# A4 vs A9
new_index = ['F', 'B']
compA4A9_events = pd.DataFrame(np.array([[42, 4], [2, 0]]),
                   columns=['F-A4', 'F-A9'], index = new_index)

# %%
compA4A9_events
# Out:
#    F-A4  F-A9
# F    42     4
# B     2     0

# %%
scipy.stats.fisher_exact(compA4A9_events, alternative='two-sided')
# Out:
# (0.0, 1.0)

# %%
##########

# %%
from matplotlib import colors
cmap = colors.ListedColormap(['red','orange','yellow','lightgrey'])
bounds=[0, 0.001, 0.01, 0.05, 1]
norm = colors.BoundaryNorm(bounds, cmap.N)

# %matplotlib notebook 
ax = plt.axes()
sns.heatmap(df1, cmap=cmap, norm =norm ,linewidths=0.5, linecolor='k', annot=True, square=True)
#ax.set_title('Behavior transition (Cell type 1 activation in A4)')
plt.show

# %%
#For Chens counted transitions 15TM (including artifact!)

# %%
new_index = ['F', 'B', 'Q']
A4_events = pd.DataFrame(np.array([[42, 3, 0], [21, 9, 0], [4, 4, 29]]),
                   columns=['F', 'B', 'Q'], index = new_index)

# %%
new_index = ['F', 'B', 'Q']
A9_events = pd.DataFrame(np.array([[3, 0, 3], [6, 2, 3], [20, 0, 18]]),
                   columns=['F', 'B', 'Q'], index = new_index)

# %%
new_index = ['F', 'B', 'Q']
A4A9_events = pd.DataFrame(np.array([[45, 3, 3], [27,11, 3], [24, 4, 46]]),
                   columns=['F', 'B', 'Q'], index = new_index)

# %%
# Fisher Exact Test 2x2
import scipy

#reshape table
#A4 or A9 events
fb = A4_events[['F', 'B']]
fb1 = fb.iloc[0:2]

#fq A4 or A9 events
fq = A4_events.iloc[[0, 2], [0, 2]]

#bq # A4 or A9 events
bq = A4_events[['B', 'Q']]
bq1 = bq.iloc[1:3]

scipy.stats.fisher_exact(bq1, alternative='two-sided')
# Out:
# (31.666666666666668, 0.000608563965059889)

# %%
##############
